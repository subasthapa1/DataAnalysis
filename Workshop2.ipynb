# %% [markdown]
# # Workshop 2

# %% [markdown]
# %matplotlib inline is used to enable the inline plotting

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# read_csv is used to read a comma-separated values(csv) file into dataframe

# %%
dataset = pd.read_csv('train_ctrUa4K.csv')

# %% [markdown]
# data.head() function returns the first n rows for the object based on position. If we don't mention number of rows, then it shows 5 rows in default.

# %%
dataset.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %% [markdown]
# Return a tuple that represents the dimensionality of the DataFrame.

# %%
dataset.shape
# Out:
# (614, 13)

# %% [markdown]
# Returns a random sample of items from a dataset.

# %%
dataset = dataset.sample(n=550, random_state=68)

# %% [markdown]
# It exports the dataframe to the specified csv file. If csv file is not available then new file with the specified name should be created.

# %%
dataset.to_csv('SubasThapa_2128468.csv')

# %%
data = pd.read_csv('SubasThapa_2128468.csv')

# %%
data.head()
# Out:
#    Unnamed: 0   Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0         193  LP001658   Male      No          0      Graduate            No
# 1         319  LP002050   Male     Yes          1      Graduate           Yes
# 2         402  LP002297   Male      No          0      Graduate            No
# 3          41  LP001120   Male      No          0      Graduate            No
# 4          68  LP001238   Male     Yes         3+  Not Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             3858                0.0        76.0             360.0
# 1            10000                0.0       155.0             360.0
# 2             2500            20000.0       103.0             360.0
# 3             1800             1213.0        47.0             360.0
# 4             7100                0.0       125.0              60.0
#
#    Credit_History Property_Area Loan_Status
# ...

# %% [markdown]
# Removes entire column with name 'Unnamed: 0'

# %%
data=data.drop('Unnamed: 0', axis = 1)

# %%
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001658   Male      No          0      Graduate            No
# 1  LP002050   Male     Yes          1      Graduate           Yes
# 2  LP002297   Male      No          0      Graduate            No
# 3  LP001120   Male      No          0      Graduate            No
# 4  LP001238   Male     Yes         3+  Not Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             3858                0.0        76.0             360.0
# 1            10000                0.0       155.0             360.0
# 2             2500            20000.0       103.0             360.0
# 3             1800             1213.0        47.0             360.0
# 4             7100                0.0       125.0              60.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0     Semiurban           Y
# 1             1.0         Rural           N
# ...

# %% [markdown]
# #### Q1. Use and explain the following DataFrame functions/properties on your data.
# describe()
# size
# ndim
# shape
# Hint: use print() to see what are the outputs.

# %%
print(data.describe())
print(data.size)
print(data.ndim)
print(data.shape)
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       550.000000         550.000000  532.000000         539.00000
# mean       5279.418182        1646.676218  145.180451         342.25603
# std        5868.489828        3028.805712   81.987789          64.68512
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2875.250000           0.000000  100.000000         360.00000
# 50%        3750.000000        1252.500000  127.000000         360.00000
# 75%        5690.500000        2253.750000  165.250000         360.00000
# max       81000.000000       41667.000000  600.000000         480.00000
#
#        Credit_History
# count      505.000000
# mean         0.835644
# std          0.370966
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# 7150
# 2
# (550, 13)

# %% [markdown]
# #### Q2. Is there any difference between dimensions of the original dataset and the new dataset? If yes, what is the difference?

# %%
dataframe1= pd.read_csv("train_ctrUa4K.csv")
newShape= data.shape
originalShape= dataframe1.shape
print("Difference between dimensions of the original dataset and the new dataset:" + str(originalShape[0]- newShape[0]))
# Out:
# Difference between dimensions of the original dataset and the new dataset:64

# %% [markdown]
# #### Q3. What are the possible values 'Education' can take? Write code to display all the possible values of 'Education'.

# %%
print('Number of unique values:' + str(data['Education'].nunique()))
print('Unique values Education can take are as follows:')
print(data['Education'].unique())
# Out:
# Number of unique values:2
# Unique values Education can take are as follows:
# ['Graduate' 'Not Graduate']

# %%
columns = data.columns
print(columns)
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001658   Male      No          0      Graduate            No
# 1  LP002050   Male     Yes          1      Graduate           Yes
# 2  LP002297   Male      No          0      Graduate            No
# 3  LP001120   Male      No          0      Graduate            No
# 4  LP001238   Male     Yes         3+  Not Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             3858                0.0        76.0             360.0
# 1            10000                0.0       155.0             360.0
# 2             2500            20000.0       103.0             360.0
# 3             1800             1213.0        47.0             360.0
# 4             7100                0.0       125.0              60.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0     Semiurban           Y
# 1             1.0         Rural           N
# ...

# %%
data['ApplicantIncome'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Q4. Use boxplot and histogram on 'ApplicantIncome' to visualise its distribution. Histogram and boxplot are used on the same feature to visualise the data distribution. Compare both the plots and report:

# %% [markdown]
# Using boxplot to visualize 'ApplicantIncome' usingboxplot.

# %%
data.boxplot(column=['ApplicantIncome'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# Using boxplot to visualize 'ApplicantIncome' using histogram.

# %%
data['ApplicantIncome'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Histogram
# * Histogram shows that there are more applicants whose salary range is between 0 to 10,000.
# * The histograms shows that there are few applicants who have salary range above 10,000 are outliers.
# * It can be inferred that most of the applicant's income in the distribution are towards the left which indicates that it is not normally distributed.
#
# Boxplot
# * Boxplot shows that median salary of the applicants is around 4000.
# * Boxplot shows that there are outliers from range 10,000 to 80,000.
# * The outliers in the boxplot indicates that there is an income disparity.

# %% [markdown]
# 4a. What are the extreme values? Are there any outliers(s) exist in this dataset? Explain with example based on
# the 'ApplicantIncome'?

# %%
data.boxplot(column='ApplicantIncome', by="Education")
# Out:
# <AxesSubplot:title={'center':'ApplicantIncome'}, xlabel='Education'>

# %% [markdown]
# 4b. Are the results of both the plots comparable? Are there any differences in the two plots? What are the key
# differences?

# %% [markdown]
# - We can see from the above boxplot that there is no significant different between the median income of graduate and non-graduate applicants. Median income for both graduates and non-graduates is around 4000.
# - There are significantly higher number of graduates with very high incomes.These graduates are appearing to be the outliers.
# - The highest ApplicantIncome of graduate applicants is 10000 while non graduate applicants is around 8000.

# %% [markdown]
# The value_counts () method returns a Series containing the counts of unique values in a specified column. For any specified column in a dataframe, this method returns the count of unique entries.

# %%
data['Credit_History'].value_counts()
# Out:
# 1.0    422
# 0.0     83
# Name: Credit_History, dtype: int64

# %%
credit_history = data['Credit_History'].value_counts(ascending=True)
loan_probability = data.pivot_table(values='Loan_Status', index=['Credit_History'],
 aggfunc=lambda x: x.map({'Y':1,'N':0}).mean())
print('Frequency Table for Credit History:')
print(credit_history)
print('\nProbability of getting loan for each Credit History class:')
print(loan_probability)
# Out:
# Frequency Table for Credit History:
# 0.0     83
# 1.0    422
# Name: Credit_History, dtype: int64
#
# Probability of getting loan for each Credit History class:
#                 Loan_Status
# Credit_History
# 0.0                0.084337
# 1.0                0.798578

# %%
data['Loan_Status'].value_counts()
# Out:
# Y    378
# N    172
# Name: Loan_Status, dtype: int64

# %%
data.shape
# Out:
# (550, 13)

# %%
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001658   Male      No          0      Graduate            No
# 1  LP002050   Male     Yes          1      Graduate           Yes
# 2  LP002297   Male      No          0      Graduate            No
# 3  LP001120   Male      No          0      Graduate            No
# 4  LP001238   Male     Yes         3+  Not Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             3858                0.0        76.0             360.0
# 1            10000                0.0       155.0             360.0
# 2             2500            20000.0       103.0             360.0
# 3             1800             1213.0        47.0             360.0
# 4             7100                0.0       125.0              60.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0     Semiurban           Y
# 1             1.0         Rural           N
# ...

# %% [markdown]
# The below code block will split the available region into a grid of plots. It will plot multiple graphs in a single window. The first plot displays number of applicants with different credit history. The second plot displays probablity of getting loan by credit history.

# %%
fig = plt.figure(figsize=(8,4))
ax1 = fig.add_subplot(121)
ax1.set_xlabel('Credit_History')
ax1.set_ylabel('Count of Applicants')
ax1.set_title("Applicants by Credit_History")
credit_history.plot(kind='bar')
plt.show()
ax2 = fig.add_subplot(122)
ax2.set_xlabel('Credit_History')
ax2.set_ylabel('Probability of getting loan')
ax2.set_title("Probability of getting loan by credit history")
loan_probability.plot(kind = 'bar')
plt.show()

# %%
data['Gender'].value_counts()
# Out:
# Male      435
# Female    103
# Name: Gender, dtype: int64

# %% [markdown]
# The below code counts the number of null values present in each column in a dataset.
# parameter axis takes 2 values:
# - axis=0 counts the null value by column
# - axis=1 counts the value by rows

# %%
data.apply(lambda x: sum(x.isnull()), axis=0)
# Out:
# Loan_ID               0
# Gender               12
# Married               2
# Dependents           13
# Education             0
# Self_Employed        31
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           18
# Loan_Amount_Term     11
# Credit_History       45
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001658   Male      No          0      Graduate            No
# 1  LP002050   Male     Yes          1      Graduate           Yes
# 2  LP002297   Male      No          0      Graduate            No
# 3  LP001120   Male      No          0      Graduate            No
# 4  LP001238   Male     Yes         3+  Not Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             3858                0.0        76.0             360.0
# 1            10000                0.0       155.0             360.0
# 2             2500            20000.0       103.0             360.0
# 3             1800             1213.0        47.0             360.0
# 4             7100                0.0       125.0              60.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0     Semiurban           Y
# 1             1.0         Rural           N
# ...

# %% [markdown]
# The below code fills the null value present in LoanAmount with mean value of the column.

# %%
data['LoanAmount'].fillna(data['LoanAmount'].mean(), inplace = True)

# %%
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001658   Male      No          0      Graduate            No
# 1  LP002050   Male     Yes          1      Graduate           Yes
# 2  LP002297   Male      No          0      Graduate            No
# 3  LP001120   Male      No          0      Graduate            No
# 4  LP001238   Male     Yes         3+  Not Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             3858                0.0        76.0             360.0
# 1            10000                0.0       155.0             360.0
# 2             2500            20000.0       103.0             360.0
# 3             1800             1213.0        47.0             360.0
# 4             7100                0.0       125.0              60.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0     Semiurban           Y
# 1             1.0         Rural           N
# ...

# %% [markdown]
# Now the null value in ApplicantIncome is replaced with mean value. We can see that 0 is displayed next to LoanAmount.

# %%
data.apply(lambda x: sum(x.isnull()), axis=0)
# Out:
# Loan_ID               0
# Gender               12
# Married               2
# Dependents           13
# Education             0
# Self_Employed        31
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     11
# Credit_History       45
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
data.shape
# Out:
# (550, 13)

# %%
data.to_csv('new_train.csv')

# %%
data.boxplot(column='LoanAmount', by = ['Education','Self_Employed'],
 grid=False, rot = 45, fontsize = 10)
# Out:
# <AxesSubplot:title={'center':'LoanAmount'}, xlabel='[Education, Self_Employed]'>

# %% [markdown]
# Count the unique values present in the column "Self_Employed"

# %%
data['Self_Employed'].value_counts()
# Out:
# No     451
# Yes     68
# Name: Self_Employed, dtype: int64

# %% [markdown]
# The below code will replace null values with "No" in Self_Employed column.

# %%
data['Self_Employed'].fillna('No', inplace=True)

# %% [markdown]
# We can see from the below output that the null values are being replaced with No.

# %%
data['Self_Employed'].value_counts()
# Out:
# No     482
# Yes     68
# Name: Self_Employed, dtype: int64

# %% [markdown]
# We can see from the below code that we have null values in Gender, Married, Dependents, Loan_Amount_Term, and Credit_History

# %%
data.apply(lambda x: sum(x.isnull()), axis=0)
# Out:
# Loan_ID               0
# Gender               12
# Married               2
# Dependents           13
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     11
# Credit_History       45
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       550.000000         550.000000  550.000000         539.00000
# mean       5279.418182        1646.676218  145.180451         342.25603
# std        5868.489828        3028.805712   80.632525          64.68512
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2875.250000           0.000000  100.000000         360.00000
# 50%        3750.000000        1252.500000  128.000000         360.00000
# 75%        5690.500000        2253.750000  162.000000         360.00000
# max       81000.000000       41667.000000  600.000000         480.00000
#
#        Credit_History
# count      505.000000
# mean         0.835644
# std          0.370966
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# Plotting a histogram with loan amount.

# %%
plt.hist(data['LoanAmount'], 20, facecolor='b')
plt.xlabel('Loan Amount')
plt.ylabel('Count')
plt.title('Histogram for loan amount')
plt.grid(True)
plt.show()

# %% [markdown]
# Plotting a boxplot for a LoanAmount column.

# %%
data.boxplot(column='LoanAmount')
# Out:
# <AxesSubplot:>

# %%
data['LoanAmount_log'] = np.log(data['LoanAmount'])
data['LoanAmount_log'].hist(bins = 20)
# Out:
# <AxesSubplot:>

# %%
plt.hist(data['LoanAmount_log'], 20, facecolor='b')
plt.xlabel('Loan Amount')
plt.ylabel('Count')
plt.title('Histogram for loan amount')
plt.grid(True)
plt.show()

# %%
data.boxplot(column='LoanAmount_log')
# Out:
# <AxesSubplot:>

# %%
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001658   Male      No          0      Graduate            No
# 1  LP002050   Male     Yes          1      Graduate           Yes
# 2  LP002297   Male      No          0      Graduate            No
# 3  LP001120   Male      No          0      Graduate            No
# 4  LP001238   Male     Yes         3+  Not Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             3858                0.0        76.0             360.0
# 1            10000                0.0       155.0             360.0
# 2             2500            20000.0       103.0             360.0
# 3             1800             1213.0        47.0             360.0
# 4             7100                0.0       125.0              60.0
#
#    Credit_History Property_Area Loan_Status  LoanAmount_log
# 0             1.0     Semiurban           Y        4.330733
# ...

# %%
data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       550.000000         550.000000  550.000000         539.00000
# mean       5279.418182        1646.676218  145.180451         342.25603
# std        5868.489828        3028.805712   80.632525          64.68512
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2875.250000           0.000000  100.000000         360.00000
# 50%        3750.000000        1252.500000  128.000000         360.00000
# 75%        5690.500000        2253.750000  162.000000         360.00000
# max       81000.000000       41667.000000  600.000000         480.00000
#
#        Credit_History  LoanAmount_log
# count      505.000000      550.000000
# mean         0.835644        4.856267
# std          0.370966        0.494792
# min          0.000000        2.197225
# 25%          1.000000        4.605170
# 50%          1.000000        4.852030
# 75%          1.000000        5.087596
# ...

# %%
data = data.drop(['LoanAmount'], axis=1)

# %% [markdown]
# Try-it-yourself: Perform some other interesting analysis which can be derived from the data. Such as:
# Check another variable for outliers and treat it.
# Generate a new variable by combining two variables e.g., 'ApplicantIncome' and 'CoapplicantIncome'.

# %% [markdown]
# Let's add ApplicantIncome and Coapplicant income and see top 10 income of a family member.

# %%
total_income = data['ApplicantIncome'] + data['CoapplicantIncome']
total_income.sort_values(ascending=False).head(10)
# Out:
# 411    81000.0
# 384    63337.0
# 216    43897.0
# 334    42083.0
# 99     39999.0
# 487    35673.0
# 367    33846.0
# 417    27500.0
# 313    24996.0
# 242    23809.0
# dtype: float64

# %%
total_income.hist(bins=20)
plt.xlabel('Total Income')
plt.ylabel('Count')
plt.title('Histogram for total income')
plt.grid(True)
plt.show()

# %% [markdown]
# The below code will find the null value fill it with mode, i.e the number which appears most often.
# [0] - Specifies column
# [1] - Specifies row

# %%
data['Gender'].fillna(data['Gender'].mode()[0], inplace = True)
 #0:gets the mode of each column, 1: for each row
data['Married'].fillna(data['Married'].mode()[0], inplace = True)
data['Dependents'].fillna(data['Dependents'].mode()[0], inplace = True)
data['Loan_Amount_Term'].fillna(data['Loan_Amount_Term'].mode()[0], inplace = True)
data['Credit_History'].fillna(data['Credit_History'].mode()[0], inplace = True)

# %% [markdown]
# Now, we can see that all null values are being replaced.

# %%
data.apply(lambda x: sum(x.isnull()), axis=0)
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# LoanAmount_log       0
# dtype: int64

# %% [markdown]
# #### Q5. Use LabelEncoder, to convert categorical variables into numeric. Hint: You will first need to identify categorial values.

# %% [markdown]
# First, we will display the data type of all columns and see if we can convert them into categorical values.

# %%
data.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# LoanAmount_log       float64
# dtype: object

# %% [markdown]
# We can see from the above list that column with data type object needs to be converted into numerical categorical values. Data type Object means variables are categorical and we need to convert them into numeric values. Object variables in our dataset above are Loan_ID, Gender, Married, Dependents, Education, Self_Employed, Property_Area, and Loan_Status. I first copied the dataframe to a new dataframe so that the below code will work accordingly.
# * We need to import LabelEncoder from sklearn.preprocessing
# * Assign class to LabelEncoder()
# * Use fit_transform() function to convert column into categorical values.

# %%
from sklearn.preprocessing import LabelEncoder
le =LabelEncoder()
data_copy = data.copy()
# Encode labels in column. 
data_copy['Gender']= le.fit_transform(data['Gender'])
data_copy['Married']= le.fit_transform(data_copy['Married'])
data_copy['Dependents']= le.fit_transform(data_copy['Dependents'])
data_copy['Education']= le.fit_transform(data_copy['Education'])
data_copy['Self_Employed']= le.fit_transform(data_copy['Self_Employed'])
data_copy['Property_Area']= le.fit_transform(data_copy['Property_Area'])
data_copy['Loan_Status']= le.fit_transform(data_copy['Loan_Status'])
data_copy['Loan_ID']= le.fit_transform(data_copy['Loan_ID'])

# %% [markdown]
# Now we can check the datatype of each column and see if they are converted into categorical values.

# %%
data_copy.dtypes
# Out:
# Loan_ID                int32
# Gender                 int32
# Married                int32
# Dependents             int32
# Education              int32
# Self_Employed          int32
# ApplicantIncome        int64
# CoapplicantIncome    float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area          int32
# Loan_Status            int32
# LoanAmount_log       float64
# dtype: object

# %%
data.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# LoanAmount_log       float64
# dtype: object

# %%
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001658   Male      No          0      Graduate            No
# 1  LP002050   Male     Yes          1      Graduate           Yes
# 2  LP002297   Male      No          0      Graduate            No
# 3  LP001120   Male      No          0      Graduate            No
# 4  LP001238   Male     Yes         3+  Not Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  Loan_Amount_Term  Credit_History  \
# 0             3858                0.0             360.0             1.0
# 1            10000                0.0             360.0             1.0
# 2             2500            20000.0             360.0             1.0
# 3             1800             1213.0             360.0             1.0
# 4             7100                0.0              60.0             1.0
#
#   Property_Area Loan_Status  LoanAmount_log
# 0     Semiurban           Y        4.330733
# 1         Rural           N        5.043425
# ...

# %%
data.shape
# Out:
# (550, 13)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
columns = list(data)
print(columns)
# Out:
# ['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status', 'LoanAmount_log']

# %%
data.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# LoanAmount_log       float64
# dtype: object

# %% [markdown]
# Create a list named "columns" by selecting columns with data type other than float64 and int64.

# %%
columns = list(data.select_dtypes(exclude=['float64','int64']))

# %%
columns
# Out:
# ['Loan_ID',
#  'Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'Property_Area',
#  'Loan_Status']

# %% [markdown]
# Loop over each item from a list "columns" and transform the values into categorical.

# %%
le = LabelEncoder()
for i in columns:
 print(i)
 data[i] = le.fit_transform(data[i])
# Out:
# Loan_ID
# Gender
# Married
# Dependents
# Education
# Self_Employed
# Property_Area
# Loan_Status

# %%
data.head()
# Out:
#    Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      171       1        0           0          0              0
# 1      281       1        1           1          0              1
# 2      362       1        0           0          0              0
# 3       39       1        0           0          0              0
# 4       63       1        1           3          1              1
#
#    ApplicantIncome  CoapplicantIncome  Loan_Amount_Term  Credit_History  \
# 0             3858                0.0             360.0             1.0
# 1            10000                0.0             360.0             1.0
# 2             2500            20000.0             360.0             1.0
# 3             1800             1213.0             360.0             1.0
# 4             7100                0.0              60.0             1.0
#
#    Property_Area  Loan_Status  LoanAmount_log
# 0              1            1        4.330733
# ...

# %%
#from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import normalize

# %%
original_data = data.copy()
original_data.head()
# Out:
#    Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      171       1        0           0          0              0
# 1      281       1        1           1          0              1
# 2      362       1        0           0          0              0
# 3       39       1        0           0          0              0
# 4       63       1        1           3          1              1
#
#    ApplicantIncome  CoapplicantIncome  Loan_Amount_Term  Credit_History  \
# 0             3858                0.0             360.0             1.0
# 1            10000                0.0             360.0             1.0
# 2             2500            20000.0             360.0             1.0
# 3             1800             1213.0             360.0             1.0
# 4             7100                0.0              60.0             1.0
#
#    Property_Area  Loan_Status  LoanAmount_log
# 0              1            1        4.330733
# ...

# %%
original_data[0:5]
# Out:
#    Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      171       1        0           0          0              0
# 1      281       1        1           1          0              1
# 2      362       1        0           0          0              0
# 3       39       1        0           0          0              0
# 4       63       1        1           3          1              1
#
#    ApplicantIncome  CoapplicantIncome  Loan_Amount_Term  Credit_History  \
# 0             3858                0.0             360.0             1.0
# 1            10000                0.0             360.0             1.0
# 2             2500            20000.0             360.0             1.0
# 3             1800             1213.0             360.0             1.0
# 4             7100                0.0              60.0             1.0
#
#    Property_Area  Loan_Status  LoanAmount_log
# 0              1            1        4.330733
# ...

# %%
data[0:5]
# Out:
#    Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      171       1        0           0          0              0
# 1      281       1        1           1          0              1
# 2      362       1        0           0          0              0
# 3       39       1        0           0          0              0
# 4       63       1        1           3          1              1
#
#    ApplicantIncome  CoapplicantIncome  Loan_Amount_Term  Credit_History  \
# 0             3858                0.0             360.0             1.0
# 1            10000                0.0             360.0             1.0
# 2             2500            20000.0             360.0             1.0
# 3             1800             1213.0             360.0             1.0
# 4             7100                0.0              60.0             1.0
#
#    Property_Area  Loan_Status  LoanAmount_log
# 0              1            1        4.330733
# ...

# %% [markdown]
# We are excluding Loan_ID and Loan_Status and normalize other data. The drop function will drop all the data by row or column.

# %%
data_for_norm = data.drop(['Loan_ID','Loan_Status'], axis=1)

# %%
normalized_data = normalize( data_for_norm )

# %%
print(normalized_data[0:5])
# Out:
# [[2.58080323e-04 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 9.95673885e-01 0.00000000e+00 9.29089161e-02
#   2.58080323e-04 2.58080323e-04 1.11767706e-03]
#  [9.99352477e-05 9.99352477e-05 9.99352477e-05 0.00000000e+00
#   9.99352477e-05 9.99352477e-01 0.00000000e+00 3.59766892e-02
#   9.99352477e-05 0.00000000e+00 5.04015938e-04]
#  [4.96059804e-05 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 1.24014951e-01 9.92119609e-01 1.78581530e-02
#   4.96059804e-05 4.96059804e-05 2.29910276e-04]
#  [4.54498982e-04 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 8.18098168e-01 5.51307266e-01 1.63619634e-01
#   4.54498982e-04 9.08997965e-04 1.74988817e-03]
#  [1.40839984e-04 1.40839984e-04 4.22519951e-04 1.40839984e-04
#   1.40839984e-04 9.99963885e-01 0.00000000e+00 8.45039903e-03
#   1.40839984e-04 2.81679968e-04 6.80019629e-04]]

# %%
normalized_data.shape
# Out:
# (550, 11)

# %%
data.shape
# Out:
# (550, 13)

# %% [markdown]
# Creating a dataframe named "normalized_data" with columns other than Loan_ID and Loan_Status.

# %%
normalized_data = pd.DataFrame(normalized_data, columns=data_for_norm.columns)

# %%
normalized_data.head()
# Out:
#      Gender   Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0  0.000258  0.000000    0.000000   0.000000       0.000000         0.995674
# 1  0.000100  0.000100    0.000100   0.000000       0.000100         0.999352
# 2  0.000050  0.000000    0.000000   0.000000       0.000000         0.124015
# 3  0.000454  0.000000    0.000000   0.000000       0.000000         0.818098
# 4  0.000141  0.000141    0.000423   0.000141       0.000141         0.999964
#
#    CoapplicantIncome  Loan_Amount_Term  Credit_History  Property_Area  \
# 0           0.000000          0.092909        0.000258       0.000258
# 1           0.000000          0.035977        0.000100       0.000000
# 2           0.992120          0.017858        0.000050       0.000050
# 3           0.551307          0.163620        0.000454       0.000909
# 4           0.000000          0.008450        0.000141       0.000282
#
#    LoanAmount_log
# 0        0.001118
# 1        0.000504
# 2        0.000230
# ...

# %% [markdown]
# Copy "Loan_ID", and "Loan_Status" columns from existing dataframe to normalized_data.

# %%
normalized_data['Loan_ID'] = data['Loan_ID']

# %%
normalized_data['Loan_Status'] = data['Loan_Status']

# %%
normalized_data.head()
# Out:
#      Gender   Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0  0.000258  0.000000    0.000000   0.000000       0.000000         0.995674
# 1  0.000100  0.000100    0.000100   0.000000       0.000100         0.999352
# 2  0.000050  0.000000    0.000000   0.000000       0.000000         0.124015
# 3  0.000454  0.000000    0.000000   0.000000       0.000000         0.818098
# 4  0.000141  0.000141    0.000423   0.000141       0.000141         0.999964
#
#    CoapplicantIncome  Loan_Amount_Term  Credit_History  Property_Area  \
# 0           0.000000          0.092909        0.000258       0.000258
# 1           0.000000          0.035977        0.000100       0.000000
# 2           0.992120          0.017858        0.000050       0.000050
# 3           0.551307          0.163620        0.000454       0.000909
# 4           0.000000          0.008450        0.000141       0.000282
#
#    LoanAmount_log  Loan_ID  Loan_Status
# 0        0.001118      171            1
# ...

# %%
normalized_data.describe()
# Out:
#            Gender     Married  Dependents   Education  Self_Employed  \
# count  550.000000  550.000000  550.000000  550.000000     550.000000
# mean     0.000182    0.000144    0.000162    0.000057       0.000022
# std      0.000125    0.000132    0.000251    0.000118       0.000068
# min      0.000000    0.000000    0.000000    0.000000       0.000000
# 25%      0.000089    0.000000    0.000000    0.000000       0.000000
# 50%      0.000195    0.000148    0.000000    0.000000       0.000000
# 75%      0.000270    0.000248    0.000279    0.000000       0.000000
# max      0.000673    0.000589    0.001609    0.000673       0.000455
#
#        ApplicantIncome  CoapplicantIncome  Loan_Amount_Term  Credit_History  \
# count       550.000000         550.000000        550.000000      550.000000
# mean          0.877320           0.308088          0.079210        0.000194
# std           0.170686           0.314175          0.038882        0.000124
# ...

# %%
normalized_data['Loan_Amount_Term'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import classification_report
from sklearn.tree import export_graphviz
from sklearn.metrics import ConfusionMatrixDisplay
import pydotplus

# %%
columns = list(normalized_data.columns) 
columns
# Out:
# ['Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'ApplicantIncome',
#  'CoapplicantIncome',
#  'Loan_Amount_Term',
#  'Credit_History',
#  'Property_Area',
#  'LoanAmount_log',
#  'Loan_ID',
#  'Loan_Status']

# %%
normalized_data.head()
# Out:
#      Gender   Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0  0.000258  0.000000    0.000000   0.000000       0.000000         0.995674
# 1  0.000100  0.000100    0.000100   0.000000       0.000100         0.999352
# 2  0.000050  0.000000    0.000000   0.000000       0.000000         0.124015
# 3  0.000454  0.000000    0.000000   0.000000       0.000000         0.818098
# 4  0.000141  0.000141    0.000423   0.000141       0.000141         0.999964
#
#    CoapplicantIncome  Loan_Amount_Term  Credit_History  Property_Area  \
# 0           0.000000          0.092909        0.000258       0.000258
# 1           0.000000          0.035977        0.000100       0.000000
# 2           0.992120          0.017858        0.000050       0.000050
# 3           0.551307          0.163620        0.000454       0.000909
# 4           0.000000          0.008450        0.000141       0.000282
#
#    LoanAmount_log  Loan_ID  Loan_Status
# 0        0.001118      171            1
# ...

# %%
features = normalized_data.drop(['Loan_ID','Loan_Status'], axis = 1)
classes = pd.DataFrame(normalized_data['Loan_Status'])

# %%
print('Features:')
print(features.head())

print('Classes:')
print(classes.head())
# Out:
# Features:
#      Gender   Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0  0.000258  0.000000    0.000000   0.000000       0.000000         0.995674
# 1  0.000100  0.000100    0.000100   0.000000       0.000100         0.999352
# 2  0.000050  0.000000    0.000000   0.000000       0.000000         0.124015
# 3  0.000454  0.000000    0.000000   0.000000       0.000000         0.818098
# 4  0.000141  0.000141    0.000423   0.000141       0.000141         0.999964
#
#    CoapplicantIncome  Loan_Amount_Term  Credit_History  Property_Area  \
# 0           0.000000          0.092909        0.000258       0.000258
# 1           0.000000          0.035977        0.000100       0.000000
# 2           0.992120          0.017858        0.000050       0.000050
# 3           0.551307          0.163620        0.000454       0.000909
# 4           0.000000          0.008450        0.000141       0.000282
#
#    LoanAmount_log
# 0        0.001118
# 1        0.000504
# ...

# %%
normalized_data.head(10)
# Out:
#      Gender   Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0  0.000258  0.000000    0.000000   0.000000       0.000000         0.995674
# 1  0.000100  0.000100    0.000100   0.000000       0.000100         0.999352
# 2  0.000050  0.000000    0.000000   0.000000       0.000000         0.124015
# 3  0.000454  0.000000    0.000000   0.000000       0.000000         0.818098
# 4  0.000141  0.000141    0.000423   0.000141       0.000141         0.999964
# 5  0.000226  0.000226    0.000000   0.000226       0.000226         0.982673
# 6  0.000267  0.000267    0.000000   0.000000       0.000000         0.805586
# 7  0.000182  0.000182    0.000182   0.000182       0.000000         0.963208
# 8  0.000244  0.000244    0.000000   0.000244       0.000000         0.929528
# 9  0.000000  0.000000    0.000000   0.000364       0.000000         0.991353
#
#    CoapplicantIncome  Loan_Amount_Term  Credit_History  Property_Area  \
# ...

# %%
normalized_data.shape
# Out:
# (550, 13)

# %%
from matplotlib import pyplot

# %%
x_train1, x_test1, y_train1, y_test1 = train_test_split(features, classes, test_size= .33, random_state = 68)
print(x_train1.shape, x_test1.shape)
# Out:
# (368, 11) (182, 11)

# %%
decisionTree1 = DecisionTreeClassifier(criterion='entropy')
print(decisionTree1)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %% [markdown]
# Train decision tree classifier

# %%
dtc_model1 = decisionTree1.fit(x_train1, y_train1)

# %%
# feature importance
importance = dtc_model1.feature_importances_
for i,v in enumerate(importance):
 print('Feature: %0d, Score: %.5f' % (i,v))
# Barchat for feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# Feature: 0, Score: 0.08117
# Feature: 1, Score: 0.07324
# Feature: 2, Score: 0.02052
# Feature: 3, Score: 0.01604
# Feature: 4, Score: 0.02083
# Feature: 5, Score: 0.12036
# Feature: 6, Score: 0.06795
# Feature: 7, Score: 0.08380
# Feature: 8, Score: 0.32799
# Feature: 9, Score: 0.04940
# Feature: 10, Score: 0.13872

# %%
prediction1 = dtc_model1.predict(x_test1)

# %%
y_true1 = le.inverse_transform(y_test1["Loan_Status"])
y_pred1 = le.inverse_transform(prediction1)

# %%
cm1 = confusion_matrix(y_true1, y_pred1)
labels = ['N', 'Y']
ConfusionMatrixDisplay(cm1, display_labels=labels).plot()

# %%
print(classification_report(y_true1, y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            N       0.42      0.46      0.44        52
#            Y       0.78      0.75      0.76       130
#
#     accuracy                           0.66       182
#    macro avg       0.60      0.60      0.60       182
# weighted avg       0.67      0.66      0.67       182

# %%
mse_dt = MSE(y_test1, prediction1)
rmse_dt =mse_dt**(1/2)
print('Root Mean Square Error for the new Decision Tree: ' + str(rmse_dt))
# Out:
# Root Mean Square Error for the new Decision Tree: 0.5789342235218394

# %%
print("Test set accuracy: {:.3f}".format(accuracy_score(y_test1, prediction1)))
#print("Accuracy: %.3f" % metrics.accuracy_score(y_test1, y_pred1))
#print("Precision: %.3f" % metrics.precision_score(y_test1, y_pred1))
#print('Recall: %.3f' % metrics.recall_score(y_test1, y_pred1))
#print('F1 Score: %.3f' % metrics.f1_score(y_test1, y_pred1))
# Out:
# Test set accuracy: 0.665

# %%
graphviz_path = 'C:\Program Files\Graphviz\bin'

# %%
import os
os.environ["PATH"] += os.pathsep + graphviz_path

# %%
from graphviz import Source
from sklearn import tree
graph = Source( tree.export_graphviz(dtc_model1, out_file=None, feature_names=features.columns))

# %%
from cairosvg import svg2png
from IPython.display import Image
svg2png(bytestring=graph.pipe(format='svg'),write_to='output.png')
Image("output.png")

# %% [markdown]
# # Report

# %% [markdown]
# #### Q6. Based on the feature importance, select a different set of features to build another decision tree model. You should aim to improve the result of the baseline model.

# %% [markdown]
# I am adding ApplicantIncome and CoapplicantIncome to see total income of a family.

# %%
normalized_data['TotalIncome'] = normalized_data['ApplicantIncome'] + normalized_data['CoapplicantIncome']

# %%
import seaborn as sns
corr_data = normalized_data.drop(['Loan_ID'], axis=1)
matrix = corr_data.corr()
f, ax = plt.subplots(figsize=(15,10))
sns.heatmap(matrix,vmax=.8,square=True,annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# - We see that the most correlated variables are (LoanAmountTerm - LoanAmount_Log ), (Credit_History - LoanAmount_log), (Credit_History — Loan_Amount_Term),(TotalIncome - LoanAmount_log), and (Loan_Status - Credit_History). I decided to select features Credit_History, LoanAmount_log, Loan_Amount_Term and ApplicantIncome.
# - We can see from the feature importance diagram for the first model that ApplicantIncome, Loan_Amount_Term, Credit_History and LoanAmount_Log has the higheest score.

# %%
new_features = normalized_data.drop(['Loan_ID','Loan_Status','Gender', 'ApplicantIncome', 'CoapplicantIncome', 'Married', 'Self_Employed','Education','Dependents','Property_Area'], axis = 1)
new_classes = pd.DataFrame(normalized_data['Loan_Status'])

# %%
print('New Features:')
print(new_features.head())

print('New Class:')
print(new_classes.head())
# Out:
# New Features:
#    Loan_Amount_Term  Credit_History  LoanAmount_log  TotalIncome
# 0          0.092909        0.000258        0.001118     0.995674
# 1          0.035977        0.000100        0.000504     0.999352
# 2          0.017858        0.000050        0.000230     1.116135
# 3          0.163620        0.000454        0.001750     1.369405
# 4          0.008450        0.000141        0.000680     0.999964
# New Class:
#    Loan_Status
# 0            1
# 1            0
# 2            1
# 3            1
# 4            1

# %%
x_train2, x_test2, y_train2, y_test2 = train_test_split(new_features, new_classes, test_size= .33, random_state = 68)
print(x_train2.shape, x_test2.shape)
# Out:
# (368, 4) (182, 4)

# %%
new_decisionTree = DecisionTreeClassifier(criterion='entropy', max_depth=4)
print(new_decisionTree)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
new_dtc_model = new_decisionTree.fit(x_train2, y_train2)

# %%
new_prediction = new_dtc_model.predict(x_test2)

# %%
print("Test set accuracy: {:.3f}".format(accuracy_score(y_test2, new_prediction)))
#print("Accuracy:",metrics.accuracy_score(y_test2, new_prediction))
#print("Precision:",metrics.precision_score(y_test2, new_prediction))
#print('Recall: %.3f' % metrics.recall_score(y_test2, new_prediction))
#print('F1 Score: %.3f' % metrics.f1_score(y_test2, new_prediction))
# Out:
# Test set accuracy: 0.802

# %%
# feature importance
importance = new_dtc_model.feature_importances_
for i,v in enumerate(importance):
 print('Feature: %0d, Score: %.5f' % (i,v))
# Barchat for feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# Feature: 0, Score: 0.09637
# Feature: 1, Score: 0.62670
# Feature: 2, Score: 0.12120
# Feature: 3, Score: 0.15573

# %%
y_true2 = le.inverse_transform(y_test2["Loan_Status"])
y_pred2 = le.inverse_transform(new_prediction)

# %%
cm2 = confusion_matrix(y_true2, y_pred2)
labels = ['N', 'Y']
ConfusionMatrixDisplay(cm2, display_labels=labels).plot()

# %%
print(classification_report(y_true2, y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            N       0.75      0.46      0.57        52
#            Y       0.81      0.94      0.87       130
#
#     accuracy                           0.80       182
#    macro avg       0.78      0.70      0.72       182
# weighted avg       0.80      0.80      0.79       182

# %%
mse_dt = MSE(y_test2, new_prediction)
rmse_dt =mse_dt**(1/2)
print('Root Mean Square Error for the new Decision Tree: ' + str(rmse_dt))
# Out:
# Root Mean Square Error for the new Decision Tree: 0.4447495899966607

# %% [markdown]
# #### Q7. Write a summary (max 250 words) to compare both the models. The summary should include: idea behind selecting those particular features and comparative analysis of the results of both the models.

# %% [markdown]
# **Ideas Behind selecting features Applicant Income, Loan_Amount_Term, Credit_History, LoanAmount_log:**
#
# * TotalIncome: TotalIncome is the sum of ApplicantIncome and CoapplicantIncome. Higher the total income of a family, higher the chances of loan approval.
# * Loan_Amount_Term: Loan Amount Term is the amount of time you have to pay back your loan. It is also the key factor in loan.
# * Credit_History: Credit history represents borrower's responsible repayment of debts. For Bank or financial institution, credit history plays the main role while approving/rejecting the loan.
# * LoanAmount_Log: Represents the loan amout of a applicant.
#
# There are few reasons for selecting the above features:
#
# **1. Analysing heatmap**
#
# We see from the above heatmap that the most correlated variables are (LoanAmountTerm - LoanAmount_Log ), (Credit_History - LoanAmount_log), (TotalIncome - LoanAmount_log), and (Credit_History — Loan_Amount_Term). I decided to select features Credit_History, LoanAmount_log, Loan_Amount_Term and TotalIncome. We can see from the feature importance diagram for the first model that ApplicantIncome, Loan_Amount_Term, Credit_History and LoanAmount_Log has the higheest score among all.
#
# **2. Creating and Selecting feature TotalIncome**
#
# Applicant Income is the main reason while approving loan .It's tedious, and banks won’t provide loan if you don’t have an income. Applicant with high income has more chances to repay loan on time. Family income is the major factor that effects loan. I have calculated total income of the family and made one feature.
#
# **3. Analysing Feature importance**
#
# We can see from the feature importance diagram for the first model that ApplicantIncome, Loan_Amount_Term, Credit_History and LoanAmount_Log has the higheest score.

# %% [markdown]
# #### Q8. Discuss the result based on the evaluation matrix (max 250 words).

# %%
print('---Classification report of the first Decision Tree---')
print(classification_report(y_true1, y_pred1))

print('---Classification report of the second Decision Tree---')
print(classification_report(y_true2, y_pred2))
# Out:
# ---Classification report of the first Decision Tree---
#               precision    recall  f1-score   support
#
#            N       0.42      0.46      0.44        52
#            Y       0.78      0.75      0.76       130
#
#     accuracy                           0.66       182
#    macro avg       0.60      0.60      0.60       182
# weighted avg       0.67      0.66      0.67       182
#
# ---Classification report of the second Decision Tree---
#               precision    recall  f1-score   support
#
#            N       0.75      0.46      0.57        52
#            Y       0.81      0.94      0.87       130
#
#     accuracy                           0.80       182
#    macro avg       0.78      0.70      0.72       182
# weighted avg       0.80      0.80      0.79       182

# %% [markdown]
# **1. Accuracy**
#
#    Accuracy of the first decision tree is 0.66 while the accuracy of the second module is 0.80. We can see that the accuracy of the mdule has been increased by 0.14.
#
# **2. Precision**
#
#    For the first decision tree, Precision for True Negative and True Positive is 0.42 and 0.78 respectively. While the second Decision Tree has a value of 0.75 and 0.81 for the True Negative and True Positive respectively. We can see that the precision values has been increased significantly. We can conclude that the second module is more accurate compared to first module.
#
# **3. Recall**
#      For the first decision tree, recall value for True Negative and True Positive are 0.46 and 0.75 respectively. While the second decision tree has a value of 0.46 and 0.94 respectively for True Negative and True Positive. It shows that the recall value has been increased by 0.19 for True Positive.
#
# **4. F1 Score**
# Weighted average F1 score for first Decision Tree is 0.67 while the score for the second module is 0.79. We can say that second Decision Tree has highest F1 score value.
#
# **5. Root Meansquare Error**
#
# Root mean square error for the first decision tree module is 0.5789342235218394, and second module is 0.4447495899966607. We can see that the root mean square value for the second decision tree module is less.
